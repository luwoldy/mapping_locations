# %%
#import dependencies
import requests
import json
import pandas as pd
import tqdm as tqdm
import folium

# %%
#place holders for dataframe
place_id = []
name = []
lat = []
lng = []

#prompt user for variables

coords = str(input('What area are you searching? Format is latitude,longitude'))
industry = input("What kind of company do you want to search for?")
search_radius = int(input('How many miles do you want to search around the area? Max: 30 miles')) * 1609.344
formatted_coords = coords.replace(" ","")
# Out:
# What area are you searching? Format is latitude,longitude35.214786, -80.860118
# What kind of company do you want to search for?hospitals
# How many miles do you want to search around the area? Max: 30 miles30

# %%
#Search Google places API with variables set by user
for i in range(0,3):
    try:

        places = requests.get(f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={coords}&radius={search_radius}&pagetoken={next_place}&keyword={industry}&key=AIzaSyC7oZBOdVCZVLK9P6gPm0g5Ed1F-uWMhD4").json()
        for i in range(len(places['results'])):
            place_id.append(places['results'][i]['name'])
            name.append(places['results'][i]['place_id'])
            lat.append(places['results'][i]['geometry']['location']['lat'])
            lng.append(places['results'][i]['geometry']['location']['lng'])

    except:
        places = requests.get(f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={coords}&radius={search_radius}&keyword={industry}&key=AIzaSyC7oZBOdVCZVLK9P6gPm0g5Ed1F-uWMhD4").json()
        for i in range(len(places['results'])):
            place_id.append(places['results'][i]['name'])
            name.append(places['results'][i]['place_id'])
            lat.append(places['results'][i]['geometry']['location']['lat'])
            lng.append(places['results'][i]['geometry']['location']['lng'])
        if places['next_page_token']:    
            next_place = places['next_page_token']

# %%
#Create a dataframe and save it to Results folder
results = pd.DataFrame({'Name':place_id, 'Place ID': name,"Latitude":lat,"Longitude":lng})
results.drop_duplicates(subset="Name")[["Name","Latitude","Longitude"]].to_csv(f"Results/{formatted_coords}_{industry}_{search_radius}.csv")

# %%
#View resulting Dataframe
results
# Out:
#                                                  Name  \
# 0           Novant Health Presbyterian Medical Center
# 1   Carolinas Medical Center-Lincoln Collins Bever...
# 2                  Carolinas HealthCare System Waxhaw
# 3                 Lake Norman Regional Medical Center
# 4               Carolinas HealthCare System NorthEast
# 5                            Carolinas Medical Center
# 6                         Carolinas Healthcare System
# 7                                 BSA Caromont Health
# 8               Novant Health Matthews Medical Center
# 9                             Atrium Health Pineville
# 10                                          Concentra
# 11                                   Heather Shiflett
# 12                        Carolinas HealthCare System
# 13                                      Novant Health
# 14                     Carolinas Medical Center-Mercy
# 15                      Atrium Health University City
# 16       Carolinas ContinueCARE Hospital at Pineville
# 17                                           Hospital
# 18        The Heart Center at Piedmont Medical Center
# 19      Carolinas ContinueCARE Hospital at University
# 20                           Atrium Health Foundation
# 21                                    One Day Surgery
# 22                                    novant hospital
# 23     W.G. (Bill) Hefner Veterans Health Care Center
# 24                      Amisub Of South Carolina, Inc
# 25                                              C M C
# 26                                           Hospital
# 27                 Presbyterian Hospital Resource Lib
# 28                                           Hospital
# 29  Levine Children's Hospital : Pediatric Resourc...
# ..                                                ...
# 50            Novant Health Hemby Children's Hospital
# 51                        Carolinas healthcare system
# 52        Novant Health Charlotte Orthopedic Hospital
# 53             Lakemont Family and Pediatric Medicine
# 54                   Carolinas Healthcare Lab Network
# 55  St. Jude Affiliate Clinic at Novant Health Hem...
# 56                                    Medicaid Office
# 57                        Carolinas HealthCare System
# 58                   CaroMont Regional Medical Center
# 59          Novant Health Huntersville Medical Center
# 60                           Atrium Health Foundation
# 61                                    One Day Surgery
# 62                                    novant hospital
# 63     W.G. (Bill) Hefner Veterans Health Care Center
# 64                      Amisub Of South Carolina, Inc
# 65                                              C M C
# 66                                           Hospital
# 67                 Presbyterian Hospital Resource Lib
# 68                                           Hospital
# 69  Levine Children's Hospital : Pediatric Resourc...
# 70            Novant Health Hemby Children's Hospital
# 71                        Carolinas healthcare system
# 72        Novant Health Charlotte Orthopedic Hospital
# 73             Lakemont Family and Pediatric Medicine
# 74                   Carolinas Healthcare Lab Network
# 75  St. Jude Affiliate Clinic at Novant Health Hem...
# 76                                    Medicaid Office
# 77                        Carolinas HealthCare System
# 78                   CaroMont Regional Medical Center
# 79          Novant Health Huntersville Medical Center
#
#                        Place ID   Latitude  Longitude
# 0   ChIJMUij1PafVogRwTdr78bMLpg  35.212174 -80.824413
# 1   ChIJ63s8tybJVogRLIglyE8IKZ0  35.490295 -81.203192
# 2   ChIJnVdWUnYpVIgRTVSNoLclUFQ  34.963982 -80.763898
# 3   ChIJsbG0cd-qVogRGbJDPQMJqxs  35.549386 -80.854110
# 4   ChIJeXV8txcPVIgR299v9MOthBY  35.437545 -80.601936
# 5   ChIJn_JBhts2VIgRKEBP4lcKwII  34.968700 -80.527610
# 6   ChIJifDt8QenVogRsQ6-27wCLkQ  35.349190 -80.843012
# 7   ChIJhXhwnr2_VogRdMcq6AZBWHw  35.270897 -81.140601
# 8   ChIJO8c8EgckVIgRnocB7dD5kwo  35.120014 -80.714052
# 9   ChIJY-mdN1-cVogR8XJU3NCrZ00  35.092199 -80.872234
# 10  ChIJ__-P3oqhVogR0gLx1TOjN2I  35.245793 -80.896187
# 11  ChIJR8QvuJ-YVogR9SVvAXFgCkw  35.223169 -80.922834
# 12  ChIJraoOIybJVogRInJI1z09opw  35.469918 -81.240331
# 13  ChIJrapqnMgdVIgR-9f6ruytSWY  35.319000 -80.776601
# 14  ChIJ99qodPqfVogR5BZkpalc1Lk  35.210628 -80.821429
# 15  ChIJpeG8ryMcVIgRCumnw9TUNWI  35.305846 -80.747021
# 16  ChIJvbcj7F6cVogROtiAkWEsMZs  35.093991 -80.872816
# 17  ChIJ_8mXJ1mcVogRwxQnAO9UzcQ  35.092821 -80.870175
# 18  ChIJrwZcIDmJVogR5zh4dpDyV0o  34.957229 -81.050518
# 19  ChIJZwLfpiMcVIgR7kSV0RQzDAI  35.306628 -80.747350
# 20  ChIJAyBLSY6fVogRbh_e-OOyA4Q  35.211200 -80.857541
# 21  ChIJWTXToJGfVogR01dCIoYSr-g  35.205057 -80.838009
# 22  ChIJI4lPHJioVogRKxXf5epYrX4  35.406135 -80.875605
# 23  ChIJVbRNW8GYVogRu1WUdKmd4nY  35.197913 -80.912590
# 24  ChIJCSaoujiJVogR_W5H0jzkXbo  34.956774 -81.051587
# 25  ChIJl4t6wD6eVogRet8sD9AymuY  35.156507 -80.828124
# 26  ChIJD1AakZGfVogR3qdcrnQ4bNg  35.205760 -80.838700
# 27  ChIJMUij1PafVogRchnEZmiy_XY  35.212018 -80.824243
# 28  ChIJC7XcyCMcVIgRx4RBLOgtsyc  35.305146 -80.746947
# 29  ChIJQ9Y4GJafVogR-dOLOqSErSs  35.197328 -80.839053
# ..                          ...        ...        ...
# 50  ChIJMUij1PafVogRKTKsVfp7a3k  35.212815 -80.824183
# 51  ChIJe4hUtGi9VogREJOXGkH0s7w  35.263761 -81.030283
# 52  ChIJW6wp3PCfVogRKm0nQMkwWEg  35.210405 -80.823591
# 53  ChIJLV-_FZnJVogR9AJsHplKNxM  35.489678 -81.203740
# 54  ChIJpSZ1aaCYVogRs8KjTlH3fb0  35.223386 -80.918963
# 55  ChIJg3P9-_afVogRYNUz_Egn4Vo  35.214334 -80.824317
# 56  ChIJbw9tXYWIVogRmEwvhct2QhI  34.934390 -80.997589
# 57  ChIJtwD7bJGfVogRte-83cE4ytQ  35.203578 -80.838852
# 58  ChIJN4KRHr2_VogRdgdXmFd4v7I  35.271433 -81.140004
# 59  ChIJtboxfY-oVogRKmowJqTa3zk  35.406381 -80.859915
# 60  ChIJAyBLSY6fVogRbh_e-OOyA4Q  35.211200 -80.857541
# 61  ChIJWTXToJGfVogR01dCIoYSr-g  35.205057 -80.838009
# 62  ChIJI4lPHJioVogRKxXf5epYrX4  35.406135 -80.875605
# 63  ChIJVbRNW8GYVogRu1WUdKmd4nY  35.197913 -80.912590
# 64  ChIJCSaoujiJVogR_W5H0jzkXbo  34.956774 -81.051587
# 65  ChIJl4t6wD6eVogRet8sD9AymuY  35.156507 -80.828124
# 66  ChIJD1AakZGfVogR3qdcrnQ4bNg  35.205760 -80.838700
# 67  ChIJMUij1PafVogRchnEZmiy_XY  35.212018 -80.824243
# 68  ChIJC7XcyCMcVIgRx4RBLOgtsyc  35.305146 -80.746947
# 69  ChIJQ9Y4GJafVogR-dOLOqSErSs  35.197328 -80.839053
# 70  ChIJMUij1PafVogRKTKsVfp7a3k  35.212815 -80.824183
# 71  ChIJe4hUtGi9VogREJOXGkH0s7w  35.263761 -81.030283
# 72  ChIJW6wp3PCfVogRKm0nQMkwWEg  35.210405 -80.823591
# 73  ChIJLV-_FZnJVogR9AJsHplKNxM  35.489678 -81.203740
# 74  ChIJpSZ1aaCYVogRs8KjTlH3fb0  35.223386 -80.918963
# 75  ChIJg3P9-_afVogRYNUz_Egn4Vo  35.214334 -80.824317
# 76  ChIJbw9tXYWIVogRmEwvhct2QhI  34.934390 -80.997589
# 77  ChIJtwD7bJGfVogRte-83cE4ytQ  35.203578 -80.838852
# 78  ChIJN4KRHr2_VogRdgdXmFd4v7I  35.271433 -81.140004
# 79  ChIJtboxfY-oVogRKmowJqTa3zk  35.406381 -80.859915
#
# [80 rows x 4 columns]

# %%
#Create the map and add all the markers
folium.Map(location=[results['Latitude'][0],results['Longitude'][0]],
    zoom_start=13)
for i in range(len(results)):
    folium.Marker([results['Latitude'][i], results['Longitude'][i]], popup=f"<i>{results['Name'][i]}</i>").add_to(m)

# %%
#View the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Save the map to the Maps folder
m.save(f"Maps/{formatted_coords}_{industry}_{search_radius}.html")
