# %%
#import dependencies
import requests
import json
import pandas as pd
import tqdm as tqdm
import folium

# %%
#place holders for dataframe
place_id = []
name = []
lat = []
lng = []

#prompt user for variables

coords = str(input('What area are you searching? Format is latitude,longitude'))
industry = input("What kind of company do you want to search for?")
search_radius = int(input('How many miles do you want to search around the area? Max: 30 miles')) * 1609.344
formatted_coords = coords.replace(" ","")
# Out:
# What area are you searching? Format is latitude,longitude35.214786, -80.860118
# What kind of company do you want to search for?schools
# How many miles do you want to search around the area? Max: 30 miles30

# %%
#Search Google places API with variables set by user
for i in range(0,3):
    try:

        places = requests.get(f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={coords}&radius={search_radius}&pagetoken={next_place}&keyword={industry}&key=AIzaSyC7oZBOdVCZVLK9P6gPm0g5Ed1F-uWMhD4").json()
        for i in range(len(places['results'])):
            place_id.append(places['results'][i]['name'])
            name.append(places['results'][i]['place_id'])
            lat.append(places['results'][i]['geometry']['location']['lat'])
            lng.append(places['results'][i]['geometry']['location']['lng'])

    except:
        places = requests.get(f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={coords}&radius={search_radius}&keyword={industry}&key=AIzaSyC7oZBOdVCZVLK9P6gPm0g5Ed1F-uWMhD4").json()
        for i in range(len(places['results'])):
            place_id.append(places['results'][i]['name'])
            name.append(places['results'][i]['place_id'])
            lat.append(places['results'][i]['geometry']['location']['lat'])
            lng.append(places['results'][i]['geometry']['location']['lng'])
        if places['next_page_token']:    
            next_place = places['next_page_token']

# %%
#Create a dataframe and save it to Results folder
results = pd.DataFrame({'Name':place_id, 'Place ID': name,"Latitude":lat,"Longitude":lng})
results.drop_duplicates(subset="Name")[["Name","Latitude","Longitude"]].to_csv(f"Results/{formatted_coords}_{industry}_{search_radius/1609.344}miles.csv")

# %%
#View resulting Dataframe
results
# Out:
#                                        Name                     Place ID  \
# 0               Iredell Statesville Schools  ChIJccVHGahUUYgR7XDf63pvWl8
# 1   Mooresville City Schools Superintendent  ChIJbcEqFuD_U4gRU6MPFFeVC60
# 2    Kannapolis City Schools Central Office  ChIJMX5UA44IVIgRQFtxcaPtHw4
# 3                  Matthews Charter Academy  ChIJ8-vEi3wkVIgRMqpwihasDcA
# 4             Forest Park Elementary School  ChIJgwNj6cMIVIgRVKa6o_OpJIE
# 5             Rocky River Elementary School  ChIJiZfJVRUAVIgROF8fGWzMfz0
# 6                   Faith Elementary School  ChIJWzWch9H0U4gR-gl4D18jcZk
# 7      Primrose School at Eastfield Village  ChIJS3sDUzQdVIgRCFaRzUlca4A
# 8          Primrose School at Park Crossing  ChIJYfhcaFecVogR6KpqWiveBjY
# 9             Charlotte Mecklenburg Schools  ChIJT_1W81D8IBURJlVOFOqN7y4
# 10            Charlotte-Mecklenburg Schools  ChIJjyCyPImjVogR3GLACbXz99U
# 11            Charlotte-Mecklenburg Schools  ChIJ3bkElhyiVogRhsKKlcHXuHg
# ...

# %%
#Create the map and add all the markers
m = folium.Map(location=[results['Latitude'][0],results['Longitude'][0]])
for i in range(len(results)):
    folium.Marker([results['Latitude'][i], results['Longitude'][i]], popup=f"<i>{results['Name'][i]}</i>").add_to(m)

# %%
#View the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Save the map to the Maps folder
m.save(f"Maps/{formatted_coords}_{industry}_{search_radius/1609.344}miles.html")
